# %%
import matplotlib.pyplot as plt
import pandas as pd
from model import TimeSeriesPredictor
import plotting

# %%
# %matplotlib inline

# %% [markdown]
# ### Выгрузим данные.

# %%
ts = pd.read_csv('../train.csv')
test = pd.read_csv('../test.csv', index_col='time', parse_dates=True)

# %%
ts.head()
# Out:
#                   time  value
# 0  2012-10-02 09:00:00   5545
# 1  2012-10-02 10:00:00   4516
# 2  2012-10-02 11:00:00   4767
# 3  2012-10-02 12:00:00   5026
# 4  2012-10-02 13:00:00   4918

# %%
test.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2017-11-18 10:00:00, 2017-11-18 11:00:00, 2017-11-18 12:00:00, 2017-11-18 13:00:00, 2017-11-18 14:00:00]

# %% [markdown]
# ### Соберем временные ряды в структуру pandas Series

# %%
ts = pd.Series(data=ts.value.values, index=pd.to_datetime(ts.time))

# %%
ts.head()
# Out:
# time
# 2012-10-02 09:00:00    5545
# 2012-10-02 10:00:00    4516
# 2012-10-02 11:00:00    4767
# 2012-10-02 12:00:00    5026
# 2012-10-02 13:00:00    4918
# dtype: int64

# %%
ts[-100:].plot()

# %% [markdown]
# ### Обучим модель.

# %%
predictor = TimeSeriesPredictor()

# %%
predictor.fit(ts)

# %% [markdown]
# ### По диапазону datetime из test, поймем, насколько точек надо сделать предсказание.

# %%
n_hours = int((test.index[-1] - test.index[0]).total_seconds() / 3600) + 1

# %%
n_hours
# Out:
# 7598

# %% [markdown]
# ### Сделаем предсказание.

# %%
ts_pred = predictor.predict_next(ts, k=n_hours)

# %%
plotting.plot_multiple_ts(ts[-500:], ts_pred[:500])
# Out:
# <div>
#
#
#             <div id="0849796f-8ea9-4df9-9702-f579adcc6d35" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0849796f-8ea9-4df9-9702-f579adcc6d35")) {
#                     Plotly.newPlot(
#                         '0849796f-8ea9-4df9-9702-f579adcc6d35',
#                         [{"type": "scatter", "uid": "da4bf09a-d9c1-49ff-ac37-de6c87fefb5c", "x": ["2017-10-28 10:00:00", "2017-10-28 11:00:00", "2017-10-28 12:00:00", "2017-10-28 13:00:00", "2017-10-28 14:00:00", "2017-10-28 15:00:00", "2017-10-28 16:00:00", "2017-10-28 17:00:00", "2017-10-28 18:00:00", "2017-10-28 19:00:00", "2017-10-28 20:00:00", "2017-10-28 21:00:00", "2017-10-28 22:00:00", "2017-10-28 23:00:00", "2017-10-29", "2017-10-29 01:00:00", "2017-10-29 02:00:00", "2017-10-29 03:00:00", "2017-10-29 04:00:00", "2017-10-29 05:00:00", "2017-10-29 06:00:00", "2017-10-29 07:00:00", "2017-10-29 08:00:00", "2017-10-29 09:00:00", "2017-10-29 10:00:00", "2017-10-29 11:00:00", "2017-10-29 12:00:00", "2017-10-29 13:00:00", "2017-10-29 14:00:00", "2017-10-29 15:00:00", "2017-10-29 16:00:00", "2017-10-29 17:00:00", "2017-10-29 18:00:00", "2017-10-29 19:00:00", "2017-10-29 20:00:00", "2017-10-29 21:00:00", "2017-10-29 22:00:00", "2017-10-29 23:00:00", "2017-10-30", "2017-10-30 01:00:00", "2017-10-30 02:00:00", "2017-10-30 03:00:00", "2017-10-30 04:00:00", "2017-10-30 05:00:00", "2017-10-30 06:00:00", "2017-10-30 07:00:00", "2017-10-30 08:00:00", "2017-10-30 09:00:00", "2017-10-30 10:00:00", "2017-10-30 11:00:00", "2017-10-30 12:00:00", "2017-10-30 13:00:00", "2017-10-30 14:00:00", "2017-10-30 15:00:00", "2017-10-30 16:00:00", "2017-10-30 17:00:00", "2017-10-30 18:00:00", "2017-10-30 19:00:00", "2017-10-30 20:00:00", "2017-10-30